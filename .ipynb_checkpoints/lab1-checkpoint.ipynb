# %% [markdown]
# # Лабораторная работа №1

# %% [markdown]
# ## Задание 1-2
# #### Загрузка данных

# %%
import pandas as pd

df = pd.read_csv('vine.dat', header=None)
df.columns =['FixedAcidity', 'VolatileAcidity', 'CitricAcid', 'ResidualSugar', 'Chlorides', 'FreeSulfurDioxide', 'TotalSulfurDioxide', 'Density', 'PH', 'Sulphates', 'Alcohol', 'Class']
df
# Out:
#       FixedAcidity  VolatileAcidity  CitricAcid  ResidualSugar  Chlorides  \
# 0              7.4            0.700        0.00            1.9      0.076
# 1              7.8            0.880        0.00            2.6      0.098
# 2              7.8            0.760        0.04            2.3      0.092
# 3             11.2            0.280        0.56            1.9      0.075
# 4              7.4            0.700        0.00            1.9      0.076
# ...            ...              ...         ...            ...        ...
# 1594           6.2            0.600        0.08            2.0      0.090
# 1595           5.9            0.550        0.10            2.2      0.062
# 1596           6.3            0.510        0.13            2.3      0.076
# 1597           5.9            0.645        0.12            2.0      0.075
# 1598           6.0            0.310        0.47            3.6      0.067
#
#       FreeSulfurDioxide  TotalSulfurDioxide  Density    PH  Sulphates  \
# 0                  11.0                34.0  0.99780  3.51       0.56
# 1                  25.0                67.0  0.99680  3.20       0.68
# 2                  15.0                54.0  0.99700  3.26       0.65
# 3                  17.0                60.0  0.99800  3.16       0.58
# 4                  11.0                34.0  0.99780  3.51       0.56
# ...                 ...                 ...      ...   ...        ...
# 1594               32.0                44.0  0.99490  3.45       0.58
# 1595               39.0                51.0  0.99512  3.52       0.76
# 1596               29.0                40.0  0.99574  3.42       0.75
# 1597               32.0                44.0  0.99547  3.57       0.71
# 1598               18.0                42.0  0.99549  3.39       0.66
#
#       Alcohol  Class
# 0         9.4      5
# 1         9.8      5
# 2         9.8      5
# 3         9.8      6
# 4         9.4      5
# ...       ...    ...
# 1594     10.5      5
# 1595     11.2      6
# 1596     11.0      6
# 1597     10.2      5
# 1598     11.0      6
#
# [1599 rows x 12 columns]

# %% [markdown]
# ## Задание 3
# #### Стандартизация

# %%
from sklearn import preprocessing
import numpy as np

# %%
Columns = ['FixedAcidity', 'VolatileAcidity', 'CitricAcid', 'ResidualSugar', 'Chlorides', 'FreeSulfurDioxide', 'TotalSulfurDioxide', 'Density', 'PH', 'Sulphates', 'Alcohol']
scaler_std = preprocessing.StandardScaler()
x = scaler_std.fit_transform(df[Columns])
df[Columns] = x
df
# Out:
#       FixedAcidity  VolatileAcidity  CitricAcid  ResidualSugar  Chlorides  \
# 0        -0.528360         0.961877   -1.391472      -0.453218  -0.243707
# 1        -0.298547         1.967442   -1.391472       0.043416   0.223875
# 2        -0.298547         1.297065   -1.186070      -0.169427   0.096353
# 3         1.654856        -1.384443    1.484154      -0.453218  -0.264960
# 4        -0.528360         0.961877   -1.391472      -0.453218  -0.243707
# ...            ...              ...         ...            ...        ...
# 1594     -1.217796         0.403229   -0.980669      -0.382271   0.053845
# 1595     -1.390155         0.123905   -0.877968      -0.240375  -0.541259
# 1596     -1.160343        -0.099554   -0.723916      -0.169427  -0.243707
# 1597     -1.390155         0.654620   -0.775267      -0.382271  -0.264960
# 1598     -1.332702        -1.216849    1.021999       0.752894  -0.434990
#
#       FreeSulfurDioxide  TotalSulfurDioxide   Density        PH  Sulphates  \
# 0             -0.466193           -0.379133  0.558274  1.288643  -0.579207
# 1              0.872638            0.624363  0.028261 -0.719933   0.128950
# 2             -0.083669            0.229047  0.134264 -0.331177  -0.048089
# 3              0.107592            0.411500  0.664277 -0.979104  -0.461180
# 4             -0.466193           -0.379133  0.558274  1.288643  -0.579207
# ...                 ...                 ...       ...       ...        ...
# 1594           1.542054           -0.075043 -0.978765  0.899886  -0.461180
# 1595           2.211469            0.137820 -0.862162  1.353436   0.601055
# 1596           1.255161           -0.196679 -0.533554  0.705508   0.542042
# 1597           1.542054           -0.075043 -0.676657  1.677400   0.305990
# 1598           0.203223           -0.135861 -0.666057  0.511130   0.010924
#
#        Alcohol  Class
# 0    -0.960246      5
# 1    -0.584777      5
# 2    -0.584777      5
# 3    -0.584777      6
# 4    -0.960246      5
# ...        ...    ...
# 1594  0.072294      5
# 1595  0.729364      6
# 1596  0.541630      6
# 1597 -0.209308      5
# 1598  0.541630      6
#
# [1599 rows x 12 columns]

# %% [markdown]
# ## Задание 4
# #### Делим на обучающую и тестовую выборки (7/3)
# ###### *Валидационная входит в обучающую и составляет 2 части

# %%
col = ['index'] + Columns + ['Class']

# %%
from sklearn.model_selection import train_test_split
train_table, test_table = train_test_split(df, train_size = 0.7)

train_table = train_table.reset_index()
test_table = test_table.reset_index()
# print(train_table, test_table)

df_test_table = pd.DataFrame(test_table, columns = col)
df_train_table = pd.DataFrame(train_table, columns = col)

print('train_table:')
df_train_table
# Out:
# train_table:
#       index  FixedAcidity  VolatileAcidity  CitricAcid  ResidualSugar  \
# 0       901     -0.528360         0.598756   -0.877968      -0.098479
# 1       111      0.046171         0.514959   -0.929318      -0.240375
# 2       363      2.401746        -0.378878    1.843607      -0.382271
# 3       466      1.137779        -0.155419    0.765247      -0.382271
# 4       107     -1.217796         0.570823    0.200392      -0.595114
# ...     ...           ...              ...         ...            ...
# 1114    613     -0.068735        -0.769931    0.559845      -0.737010
# 1115    829     -1.390155         0.459094   -0.980669      -0.311323
# 1116   1263     -0.068735         1.408795   -1.391472      -0.240375
# 1117    172     -0.183641        -0.602337   -0.518514      -0.382271
# 1118   1470      0.965420         0.906012   -0.826617      -0.807957
#
#       Chlorides  FreeSulfurDioxide  TotalSulfurDioxide   Density        PH  \
# 0     -0.158692           0.011961           -0.409542  0.325068  1.742192
# 1     -0.073677          -0.466193            1.871131 -0.183745 -1.043897
# 2     -0.349975          -0.944346           -0.956903  1.088288 -2.080582
# 3     -0.392483           0.490115            0.137820  0.770280 -0.979104
# 4      0.011338          -0.083669            0.533136  0.081262  0.964679
# ...         ...                ...                 ...       ...       ...
# 1114  -0.626274          -0.561823           -0.531178 -0.289747 -0.331177
# 1115  -0.349975           0.011961           -0.683222 -1.582981  1.612607
# 1116   0.032592          -0.274931           -0.622404  0.558274  0.381544
# 1117  -0.307468          -0.944346           -0.865676  0.240266 -0.136798
# 1118  -0.073677          -0.753085           -0.683222 -0.512353 -2.793302
#
#       Sulphates   Alcohol  Class
# 0      0.187963  0.353895      7
# 1      0.010924 -0.584777      5
# 2      1.250199 -0.209308      5
# 3      0.365003  1.010966      6
# 4      0.778094 -1.054113      5
# ...         ...       ...    ...
# 1114   0.483029 -0.584777      5
# 1115   0.660068  0.635497      6
# 1116  -1.169337 -0.772512      4
# 1117  -0.284141 -1.147981      6
# 1118  -1.110324 -0.678644      5
#
# [1119 rows x 13 columns]

# %%
print('test_table:')
df_test_table
# Out:
# test_table:
#      index  FixedAcidity  VolatileAcidity  CitricAcid  ResidualSugar  \
# 0      216      0.218530         0.542891   -0.569865      -0.382271
# 1      597      2.057027         0.291499    1.586855      -0.453218
# 2     1533     -0.183641        -0.769931    0.149042      -0.453218
# 3       47      0.218530        -1.328579    1.278752      -0.666062
# 4     1331     -0.298547         1.911578   -0.056360       0.894790
# ..     ...           ...              ...         ...            ...
# 475    821     -1.964686        -0.602337   -1.391472      -0.311323
# 476    902     -0.528360         0.598756   -0.877968      -0.098479
# 477    721      0.333436        -0.267148   -0.159061       0.220786
# 478   1310     -0.470907         0.459094   -0.056360      -0.453218
# 479    333      0.046171         0.179770   -0.980669      -0.311323
#
#      Chlorides  FreeSulfurDioxide  TotalSulfurDioxide   Density        PH  \
# 0     0.287636          -0.274931            0.077002 -0.289747 -1.108690
# 1    -0.349975          -1.039977           -0.865676  0.664277 -1.432654
# 2    -0.286214           1.542054            1.141316  0.224366  0.511130
# 3     0.542681          -0.370562           -0.287906  0.081262 -0.395969
# 4     0.415159           1.446423            0.624363 -0.035341 -0.331177
# ..         ...                ...                 ...       ...       ...
# 475  -0.838811           0.011961           -0.135861 -2.759611  2.584499
# 476  -0.158692           0.011961           -0.409542  0.325068  1.742192
# 477   0.138860           1.828946            1.810313  0.770280 -1.367861
# 478  -0.307468           0.777007            1.262952 -0.332149 -0.072005
# 479   0.372651           0.011961           -0.075043 -0.501753 -1.173483
#
#      Sulphates   Alcohol  Class
# 0    -0.520193  0.541630      5
# 1    -0.166115 -0.397043      6
# 2    -0.284141 -1.335715      5
# 3    -0.461180 -0.866379      5
# 4    -1.169337 -1.147981      5
# ..         ...       ...    ...
# 475   0.483029  3.357647      7
# 476   0.187963  0.353895      7
# 477  -0.756246 -1.147981      5
# 478  -0.756246 -0.584777      5
# 479  -0.815259  0.541630      5
#
# [480 rows x 13 columns]

# %% [markdown]
# ## Задание 5
# #### Деревья решений

# %%
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.metrics import confusion_matrix

def MakingTree(crit, alpha):
    clf = tree.DecisionTreeClassifier(criterion = crit, ccp_alpha = alpha)
    clf.fit(train_table[Columns], train_table[['Class']])
    
    # res = clf.predict(test_table[['FixedAcidity', 'VolatileAcidity', 'CitricAcid', 'ResidualSugar', 'Chlorides', 'FreeSulfurDioxide', 'TotalSulfurDioxide', 'Density', 'PH', 'Sulphates', 'Alcohol']])
    # print(confusion_matrix(test_table, res))

    tree.plot_tree(clf,filled = True, rounded = True)
    plt.savefig('tree.pdf') ##для сохранение в пдф
    plt.show
    
    # Классифицируем тестовую выборку и находим процент совпадения
    print(clf.score(test_table[Columns], test_table[['Class']]))

# %% [markdown]
# ## По Джинни

# %%
MakingTree('gini', 0.005)
# Out:
# 0.5229166666666667

# %%
MakingTree('gini', 0.012)
print("Хорошая Дженни")
# Out:
# 0.56875
# Хорошая Дженни

# %%
MakingTree('gini', 0.015)
# Out:
# 0.56875

# %%
MakingTree('gini', 0.02)
# Out:
# 0.5708333333333333

# %%
MakingTree('gini', 0.03)
# Out:
# 0.5708333333333333

# %%
MakingTree('gini', 0.2)
# Out:
# 0.4125

# %%
MakingTree('gini', 0.8)
# Out:
# 0.4125

# %% [markdown]
# ## По энтропии

# %%
MakingTree('entropy', 0.005)
# Out:
# 0.6020833333333333

# %%
MakingTree('entropy', 0.01)
# Out:
# 0.58125

# %%
MakingTree('entropy', 0.015)
# Out:
# 0.5875

# %%
MakingTree('entropy', 0.02)
# Out:
# 0.5833333333333334

# %%
MakingTree('entropy', 0.025)
# Out:
# 0.5833333333333334

# %%
MakingTree('entropy', 0.03)
# Out:
# 0.5708333333333333

# %%
MakingTree('entropy', 0.035)
# Out:
# 0.5708333333333333

# %%
MakingTree('entropy', 0.2)
# Out:
# 0.4125

# %%
MakingTree('entropy', 0.8)
# Out:
# 0.4125

# %% [markdown]
# #### Для энтропии наилучшим дерево является при альфа = 0.025 с 58,33%
# #### Для коэффициента Джинни наилучшим дерево является при альфа = 0.012 с 56,88%
